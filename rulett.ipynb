# %%
from random import randint
import matplotlib.pyplot as plt 

tot = 0
antsim = 10
ant = 100_000
sim = []
revsim = []
for i in range(1, antsim+1):
    person1 = 0
    
    for rulett in range(1, ant+1):
        
        gønner = [0 for x in range(6)]
        gønner[randint(0, 5)] = 1

        if gønner.index(1)%2 == 0:
            person1 += 1

        revsim.append(person1/rulett)

    if person1/ant > 0.5:
        tot+=1 

    sim.append(revsim)
    plt.plot(revsim)
    revsim = []


#plt.plot(sim)
plt.ylim([0.45, 0.55])
plt.hlines(0.5, 0, ant, 'red')
#plt.show()
