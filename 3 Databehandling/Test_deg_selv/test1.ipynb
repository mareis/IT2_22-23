# %%
import pandas as pd

df = pd.read_csv("konsumprisindeks.csv", sep=";", decimal=",")
df
# Out:
#      aar  snitt    Jan    Feb    Mar    Apr    Mai    Jun    Jul    Aug  \
# 0   2022    NaN  117.8  119.1  119.8  121.2  121.5  122.6  124.2  123.9
# 1   2021  116.1  114.1  114.9  114.6  115.0  114.9  115.3  116.3  116.3
# 2   2020  112.2  111.3  111.2  111.2  111.7  111.9  112.1  112.9  112.5
# 3   2019  110.8  109.3  110.2  110.4  110.8  110.5  110.6  111.4  110.6
# 4   2018  108.4  106.0  107.0  107.3  107.7  107.8  108.5  109.3  108.9
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 89  1933    2.7    2.7    2.7    2.7    2.7    2.7    2.7    2.7    2.8
# 90  1932    2.8    2.8    2.8    2.8    2.8    2.8    2.8    2.8    2.8
# 91  1931    2.8    2.9    2.9    2.9    2.9    2.8    2.8    2.8    2.8
# 92  1930    3.0    3.0    3.0    3.0    3.0    3.0    3.0    3.0    3.0
# 93  1929    3.1    3.1    3.1    3.1    3.1    3.1    3.1    3.1    3.1
#
#       Sep    Okt    Nov    Des
# 0   125.6    NaN    NaN    NaN
# 1   117.5  117.2  118.1  118.9
# ...

# %%
df.describe()
# Out:
#                aar       snitt         Jan         Feb         Mar  \
# count    94.000000   93.000000   94.000000   94.000000   94.000000
# mean   1975.500000   38.609677   38.818085   39.015957   39.197872
# std      27.279418   36.969550   37.261976   37.475119   37.564416
# min    1929.000000    2.700000    2.700000    2.700000    2.700000
# 25%    1952.250000    6.700000    6.575000    6.650000    6.650000
# 50%    1975.500000   19.200000   19.250000   19.350000   19.600000
# 75%    1998.750000   71.500000   71.975000   72.125000   72.600000
# max    2022.000000  116.100000  117.800000  119.100000  119.800000
#
#               Apr         Mai         Jun         Jul         Aug         Sep  \
# count   94.000000   94.000000   94.000000   94.000000   94.000000   94.000000
# mean    39.327660   39.371277   39.480851   39.589362   39.517021   39.810638
# std     37.690569   37.706121   37.769261   37.840618   37.729697   38.022997
# ...

# %%
import numpy as np
minimum = df[["aar", "Jan", "Feb", "Mar", "Apr", "Mai", "Jun", "Jul", "Aug", "Sep", "Okt", "Nov", "Des"]].groupby("aar").min().min()

i = list(np.where(df == minimum))[0]
aar = df["aar"][i] 
data = [aar, minimum]

minimum_df = pd.DataFrame(data, columns=['aar, min'])
minimum_df
data[0]
# Out:
# /var/folders/0h/pp5g9p3x6yb_j3l0x6s_hz4r0000gn/T/ipykernel_88361/954152538.py:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   i = list(np.where(df == minimum))[0]
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /Users/madsor/Library/CloudStorage/OneDrive-MøreogRomsdalFylkeskommune/00_MoldeVGS/IT-2/IT2_22-23/3 Databehandling/Test_deg_selv/test1.ipynb Cell 3 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/madsor/Library/CloudStorage/OneDrive-M%C3%B8reogRomsdalFylkeskommune/00_MoldeVGS/IT-2/IT2_22-23/3%20Databehandling/Test_deg_selv/test1.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> aar = df["aar"][i]
# ...

# %%
df.index[df['BoolCol']].tolist()
# Out:
# 0     NaN
# 1     4.8
# 2     1.6
# 3     2.0
# 4     3.8
#      ...
# 89    0.0
# 90    0.0
# 91   -0.1
# 92   -0.1
# 93    0.0
# Length: 94, dtype: float64

# %%
df.iloc[:, 2:].max().sort_values()
# Out:
# Okt    117.2
# Jan    117.8
# Nov    118.1
# Des    118.9
# Feb    119.1
# Mar    119.8
# Apr    121.2
# Mai    121.5
# Jun    122.6
# Aug    123.9
# Jul    124.2
# Sep    125.6
# dtype: float64
