# %%
import pandas as pd

data = pd.read_csv("https://data.ssb.no/api/v0/dataset/1066.csv?lang=no", sep=';', decimal=',', encoding = "ISO-8859-1", )

data
# Out:
#                                           næring    måned  \
# 0   47 Detaljhandel, unntatt salg av motorvogner  2021M11
# 1   47 Detaljhandel, unntatt salg av motorvogner  2021M12
# 2   47 Detaljhandel, unntatt salg av motorvogner  2022M01
# 3   47 Detaljhandel, unntatt salg av motorvogner  2022M02
# 4   47 Detaljhandel, unntatt salg av motorvogner  2022M03
# 5   47 Detaljhandel, unntatt salg av motorvogner  2022M04
# 6   47 Detaljhandel, unntatt salg av motorvogner  2022M05
# 7   47 Detaljhandel, unntatt salg av motorvogner  2022M06
# 8   47 Detaljhandel, unntatt salg av motorvogner  2022M07
# 9   47 Detaljhandel, unntatt salg av motorvogner  2022M08
# 10  47 Detaljhandel, unntatt salg av motorvogner  2022M09
# 11  47 Detaljhandel, unntatt salg av motorvogner  2022M10
# 12  47 Detaljhandel, unntatt salg av motorvogner  2022M11
#
#             statistikkvariabel  \
# 0   Volumindeks, sesongjustert
# 1   Volumindeks, sesongjustert
# 2   Volumindeks, sesongjustert
# ...
