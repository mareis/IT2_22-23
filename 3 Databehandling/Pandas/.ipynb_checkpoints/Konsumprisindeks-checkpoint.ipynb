# %%
import pandas as pd
df = pd.read_csv("konsumprisindeks.csv", sep=";", decimal=",")
df.head()
# Out:
#    Unnamed: 0  Årsgj.snitt2    Jan    Feb    Mar    Apr    Mai    Jun    Jul  \
# 0        2022           NaN  117.8  119.1  119.8  121.2  121.5  122.6  124.2
# 1        2021         116.1  114.1  114.9  114.6  115.0  114.9  115.3  116.3
# 2        2020         112.2  111.3  111.2  111.2  111.7  111.9  112.1  112.9
# 3        2019         110.8  109.3  110.2  110.4  110.8  110.5  110.6  111.4
# 4        2018         108.4  106.0  107.0  107.3  107.7  107.8  108.5  109.3
#
#      Aug    Sep    Okt    Nov    Des
# 0  123.9  125.6    NaN    NaN    NaN
# 1  116.3  117.5  117.2  118.1  118.9
# 2  112.5  112.9  113.2  112.4  112.9
# 3  110.6  111.1  111.3  111.6  111.3
# 4  108.9  109.5  109.3  109.8  109.8

# %%
df = df.rename(columns={"Unnamed: 0": "Ar", "Årsgj.snitt2": "Gjennomsnitt"})
df.head()
# Out:
#      Ar  Gjennomsnitt    Jan    Feb    Mar    Apr    Mai    Jun    Jul    Aug  \
# 0  2022           NaN  117.8  119.1  119.8  121.2  121.5  122.6  124.2  123.9
# 1  2021         116.1  114.1  114.9  114.6  115.0  114.9  115.3  116.3  116.3
# 2  2020         112.2  111.3  111.2  111.2  111.7  111.9  112.1  112.9  112.5
# 3  2019         110.8  109.3  110.2  110.4  110.8  110.5  110.6  111.4  110.6
# 4  2018         108.4  106.0  107.0  107.3  107.7  107.8  108.5  109.3  108.9
#
#      Sep    Okt    Nov    Des
# 0  125.6    NaN    NaN    NaN
# 1  117.5  117.2  118.1  118.9
# 2  112.9  113.2  112.4  112.9
# 3  111.1  111.3  111.6  111.3
# 4  109.5  109.3  109.8  109.8

# %%
df.columns
# Out:
# Index(['Ar', 'Gjennomsnitt', 'Jan', 'Feb', 'Mar', 'Apr', 'Mai', 'Jun', 'Jul',
#        'Aug', 'Sep', 'Okt', 'Nov', 'Des'],
#       dtype='object')

# %%
maneder = ['Jan', 'Feb', 'Mar', 'Apr', 'Mai', 'Jun', 'Jul',
       'Aug', 'Sep', 'Okt', 'Nov', 'Des']
             
df_min = df.loc[df[maneder].idxmin()].drop_duplicates(['Ar'], keep='first')
df_min.index = df_min.Ar
df_min = df_min[maneder].head(2)

# %%
df_maks = df.loc[df[maneder].idxmax()].drop_duplicates(['Ar'], keep='first')
df_maks.index = df_maks.Ar
df_maks = df_maks[maneder].head(1)

# %%
maks = df[maneder].max().max()
minn = df[maneder].min().min()

def apply_color(v):
    if v  == minn:
        return "background-color: green"
    if v == maks:
         return "background-color: red"
    else:
        return "color: white"

df_min = df_min.drop(columns=["Aug"])
df_min.style.applymap(apply_color)
# Out:
# <style type="text/css">
# #T_38d36_row0_col0, #T_38d36_row0_col1, #T_38d36_row0_col2, #T_38d36_row0_col3, #T_38d36_row0_col4, #T_38d36_row0_col5, #T_38d36_row1_col0, #T_38d36_row1_col1, #T_38d36_row1_col2, #T_38d36_row1_col3, #T_38d36_row1_col4, #T_38d36_row1_col5, #T_38d36_row1_col6, #T_38d36_row1_col7, #T_38d36_row1_col8, #T_38d36_row1_col9, #T_38d36_row1_col10 {
#   background-color: green;
# }
# #T_38d36_row0_col6, #T_38d36_row0_col7, #T_38d36_row0_col8, #T_38d36_row0_col9, #T_38d36_row0_col10 {
#   color: white;
# }
# </style>
# <table id="T_38d36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38d36_level0_col0" class="col_heading level0 col0" >Jan</th>
#       <th id="T_38d36_level0_col1" class="col_heading level0 col1" >Feb</th>
#       <th id="T_38d36_level0_col2" class="col_heading level0 col2" >Mar</th>
#       <th id="T_38d36_level0_col3" class="col_heading level0 col3" >Apr</th>
#       <th id="T_38d36_level0_col4" class="col_heading level0 col4" >Mai</th>
#       <th id="T_38d36_level0_col5" class="col_heading level0 col5" >Jun</th>
#       <th id="T_38d36_level0_col6" class="col_heading level0 col6" >Jul</th>
#       <th id="T_38d36_level0_col7" class="col_heading level0 col7" >Sep</th>
#       <th id="T_38d36_level0_col8" class="col_heading level0 col8" >Okt</th>
#       <th id="T_38d36_level0_col9" class="col_heading level0 col9" >Nov</th>
#       <th id="T_38d36_level0_col10" class="col_heading level0 col10" >Des</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ar</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38d36_level0_row0" class="row_heading level0 row0" >1934</th>
#       <td id="T_38d36_row0_col0" class="data row0 col0" >2.700000</td>
#       <td id="T_38d36_row0_col1" class="data row0 col1" >2.700000</td>
#       <td id="T_38d36_row0_col2" class="data row0 col2" >2.700000</td>
#       <td id="T_38d36_row0_col3" class="data row0 col3" >2.700000</td>
#       <td id="T_38d36_row0_col4" class="data row0 col4" >2.700000</td>
#       <td id="T_38d36_row0_col5" class="data row0 col5" >2.700000</td>
#       <td id="T_38d36_row0_col6" class="data row0 col6" >2.800000</td>
#       <td id="T_38d36_row0_col7" class="data row0 col7" >2.800000</td>
#       <td id="T_38d36_row0_col8" class="data row0 col8" >2.800000</td>
#       <td id="T_38d36_row0_col9" class="data row0 col9" >2.800000</td>
#       <td id="T_38d36_row0_col10" class="data row0 col10" >2.800000</td>
#     </tr>
#     <tr>
#       <th id="T_38d36_level0_row1" class="row_heading level0 row1" >1933</th>
#       <td id="T_38d36_row1_col0" class="data row1 col0" >2.700000</td>
#       <td id="T_38d36_row1_col1" class="data row1 col1" >2.700000</td>
#       <td id="T_38d36_row1_col2" class="data row1 col2" >2.700000</td>
#       <td id="T_38d36_row1_col3" class="data row1 col3" >2.700000</td>
#       <td id="T_38d36_row1_col4" class="data row1 col4" >2.700000</td>
#       <td id="T_38d36_row1_col5" class="data row1 col5" >2.700000</td>
#       <td id="T_38d36_row1_col6" class="data row1 col6" >2.700000</td>
#       <td id="T_38d36_row1_col7" class="data row1 col7" >2.700000</td>
#       <td id="T_38d36_row1_col8" class="data row1 col8" >2.700000</td>
#       <td id="T_38d36_row1_col9" class="data row1 col9" >2.700000</td>
#       <td id="T_38d36_row1_col10" class="data row1 col10" >2.700000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_maks = df_maks[["Sep"]]
df_maks.style.applymap(apply_color)
# Out:
# <style type="text/css">
# #T_74bc1_row0_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_74bc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74bc1_level0_col0" class="col_heading level0 col0" >Sep</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ar</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74bc1_level0_row0" class="row_heading level0 row0" >2022</th>
#       <td id="T_74bc1_row0_col0" class="data row0 col0" >125.600000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Diff'] = (df.Jan-df.Des).abs()
df.Diff.max()
# Out:
# 4.800000000000011

# %%
diff = df.loc[df.Diff == df.Diff.max()]
diff[['Ar', 'Jan', 'Des', 'Diff']]
# Out:
#      Ar    Jan    Des  Diff
# 1  2021  114.1  118.9   4.8

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['ggplot'])
sns.set_palette("deep", 10)

# %%
plt.title("Konsumprisindeks")
sns.lineplot(x="Ar", 
            y="Gjennomsnitt",
            data=df)
plt.show()

# %%
df_2022 = df.head(1).dropna(axis=1)
df_2022 = df_2022.drop(columns=["Ar"])
df_2022
# Out:
#      Jan    Feb    Mar    Apr    Mai    Jun    Jul    Aug    Sep
# 0  117.8  119.1  119.8  121.2  121.5  122.6  124.2  123.9  125.6

# %%
plt.title("Konsumprisindeks i 2022")
sns.barplot(x = df_2022.columns,y=df_2022.values[0])
plt.show()

# %%
df.filter(items=[88], axis=0)
# Out:
#       Ar  Gjennomsnitt  Jan  Feb  Mar  Apr  Mai  Jun  Jul  Aug  Sep  Okt  Nov  \
# 88  1934           2.8  2.7  2.7  2.7  2.7  2.7  2.7  2.8  2.8  2.8  2.8  2.8
#
#     Des  Diff
# 88  2.8   0.1

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
