# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use(['ggplot'])
sns.set_palette("deep", 10)

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('penguins')
df.head()
sns.load_dataset('car_crashes')
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df=df.dropna()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
antall_art = df['species'].value_counts()
antall_art
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.groupby('island')['body_mass_g'].sum()
# Out:
# island
# Biscoe       769225.0
# Dream        457425.0
# Torgersen    174300.0
# Name: body_mass_g, dtype: float64

# %% [markdown]
# ## 3)
#
# Minste vingespenn (feat. T-Dog Lækka)

# %%
df.groupby('species')['flipper_length_mm'].min()
# Out:
# species
# Adelie       172.0
# Chinstrap    178.0
# Gentoo       203.0
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# Lengste vingespenn (feat. T-Dog Lækka)

# %%
df.groupby('species')['flipper_length_mm'].max()
# Out:
# species
# Adelie       210.0
# Chinstrap    212.0
# Gentoo       231.0
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# The J way!!!

# %%
df.groupby('species')['flipper_length_mm'].agg(['min', 'max'])
# Out:
#              min    max
# species
# Adelie     172.0  210.0
# Chinstrap  178.0  212.0
# Gentoo     203.0  231.0

# %% [markdown]
# ## 4
#
# Dag all the way!

# %%
df.groupby(['species', 'sex'])['body_mass_g'].median()
# Out:
# species    sex
# Adelie     Female    3400.0
#            Male      4000.0
# Chinstrap  Female    3550.0
#            Male      3950.0
# Gentoo     Female    4700.0
#            Male      5500.0
# Name: body_mass_g, dtype: float64

# %%
df.sort_values(by=['bill_depth_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 244  Gentoo     Biscoe            42.9           13.1              215.0
# 220  Gentoo     Biscoe            46.1           13.2              211.0
# 268  Gentoo     Biscoe            44.9           13.3              213.0
# 228  Gentoo     Biscoe            43.3           13.4              209.0
# 236  Gentoo     Biscoe            42.0           13.5              210.0
# ..      ...        ...             ...            ...                ...
# 35   Adelie      Dream            39.2           21.1              196.0
# 61   Adelie     Biscoe            41.3           21.1              195.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
#
#      body_mass_g     sex
# 244       5000.0  Female
# 220       4500.0  Female
# ...

# %%
sns.barplot(x=antall_art.index, y=antall_art)
plt.show()

# %%
antall_art = df.groupby('species').count()['island']
sns.barplot(x=antall.index, y=antall_art)
plt.show()

# %%
antall_øy = df['island'].value_counts()
sns.barplot(x=antall_øy.index, y=antall_øy)
plt.show()

# %%
antall_kjønn = df['sex'].value_counts()
sns.barplot(x=antall_kjønn.index, y=antall_kjønn)
plt.show()

# %%
sns.barplot(
    x="species", 
    y="body_mass_g",
    hue='sex',
    data=df)
plt.show()

# %%
sns.boxplot(y = 'body_mass_g', x = 'species', hue = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.pairplot(df, hue = 'species')
plt.show()

# %%
sns.heatmap(df.groupby('species').corr(), annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:ylabel='species-None'>
